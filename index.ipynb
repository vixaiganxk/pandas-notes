# %% [markdown]
# # Pandas Fundamentals

# %% [markdown]
# ## Index
# 1. Definition
#     - Indexing allows quick access to the rows and elements of the dataframe.
#     - Enables faster querying.

# %%
#Creating dataframe
import pandas as pd
people = {
    'first_name': ['Magic', 'Old', 'Jack', 'Johnnie'],
    'last_name': ['Moments', 'Monk', 'Daniels', 'Walker'],
    'email_ID': ['mmoments@gmail.com', 'oldmonk@yahoo.com', 'jackdaniel@jack.com', 'Miki@tyson.com'],
    'contact_no': [9823983242, 4327847238, 6739297423, 7889732131]
}

people_df = pd.DataFrame(people)
people_df
# Out:
#   first_name last_name             email_ID  contact_no
# 0      Magic   Moments   mmoments@gmail.com  9823983242
# 1        Old      Monk    oldmonk@yahoo.com  4327847238
# 2       Jack   Daniels  jackdaniel@jack.com  6739297423
# 3    Johnnie    Walker       Miki@tyson.com  7889732131

# %% [markdown]
# ### 1. Creating index after dataframe creation

# %%
people_df.set_index('contact_no') #---><Here contact number becomes the index now but not in place><---
people_df.head()

#Creating index in inplace
people_df.set_index('contact_no', inplace=True)
people_df.head()
# Out:
#            first_name last_name             email_ID
# contact_no
# 9823983242      Magic   Moments   mmoments@gmail.com
# 4327847238        Old      Monk    oldmonk@yahoo.com
# 6739297423       Jack   Daniels  jackdaniel@jack.com
# 7889732131    Johnnie    Walker       Miki@tyson.com

# %% [markdown]
# ### 2. Index of the dataframe

# %%
#Lists the index of the dataframe
people_df.index
# Out:
# Index([9823983242, 4327847238, 6739297423, 7889732131], dtype='int64', name='contact_no')

# %% [markdown]
# ### 3. Accessing the dataframe using index

# %%
#To get all the elements of that index
people_df.loc[7889732131, :]

#To filter specific element of a specific index
people_df.loc[9823983242, 'email_ID']

#Accessing with iloc will be normal after creating index
people_df.iloc[1:3, :]
people_df.iloc[:, [0,2]]
people_df.iloc[[0,1,2],:]
# Out:
#            first_name last_name             email_ID
# contact_no
# 9823983242      Magic   Moments   mmoments@gmail.com
# 4327847238        Old      Monk    oldmonk@yahoo.com
# 6739297423       Jack   Daniels  jackdaniel@jack.com

# %% [markdown]
# ### 4. Resetting the index

# %%
#Executing this code block multiple times create multiple index levels upto 2
people_df.reset_index(inplace=True)
people_df.head()
# Out:
#    contact_no first_name last_name             email_ID
# 0  9823983242      Magic   Moments   mmoments@gmail.com
# 1  4327847238        Old      Monk    oldmonk@yahoo.com
# 2  6739297423       Jack   Daniels  jackdaniel@jack.com
# 3  7889732131    Johnnie    Walker       Miki@tyson.com

# %% [markdown]
# ### 5. Setting & Resetting the set_options in Pandas

# %%
#Reading a csv for dataframe
file_path = './data/Otodom_Poland.csv'
dataframe = pd.read_csv(file_path, encoding='latin1')

# %%
#Setting the display options
pd.set_option('display.max_rows', 5) #---Will display only 5 rows 
pd.set_option('display.max_columns', 5) #----Will display only 5 columns
dataframe
# Out:
#       timestamp                                              title  ...  \
# 0    2023-09-04  Radom / os. Ustronie / 3 pokoje / do odÅwieÅ¼...  ...
# 1    2023-09-04   Sprzedam 2 pok bezczynszowe mieszkanie w Tucholi  ...
# ..          ...                                                ...  ...
# 998  2023-09-04                   okolice Podwala PEÅEN ROZKÅAD!  ...
# 999  2023-09-04    Gotowy dom , wysoki standard ,dobra lokalizacja  ...
#
#     is_for_sale posting_id
# 0          True      4hFJH
# 1          True      4inHn
# ..          ...        ...
# 998        True      4jXK7
# 999        True      4ljMd
#
# [1000 rows x 15 columns]

# %%
#Resetting the display options
pd.reset_option('display.max_columns') #---Reset the set_option for columns, later displays normal no.of columns
pd.reset_option('display.max_rows') #---Reset the set_option for rows, later displays normal no.of rows

#Prints the dataframe
dataframe
# Out:
#       timestamp                                              title    price  \
# 0    2023-09-04  Radom / os. Ustronie / 3 pokoje / do odÅwieÅ¼...   350000
# 1    2023-09-04   Sprzedam 2 pok bezczynszowe mieszkanie w Tucholi   219000
# 2    2023-09-04              RacÅawicka Platinum | mieszkanie 3-6   654192
# 3    2023-09-04   Sosnowiec, mieszkanie z tarasem 9m2 Stary Browar   393924
# 4    2023-09-04  Segmenty na sprzedaÅ¼ w Karolinie - ostatni lo...   590000
# ..          ...                                                ...      ...
# 995  2023-09-04  Bezczynszowe osiedle |Pomoc w programie 2% kre...   519000
# 996  2023-09-04       OKAZJA, 1/2 pokoje, NOWE, klucze w LIPCU !!!   269000
# 997  2023-09-04            OGRÃDEK | Najlepsza CENA | ostatnie !!   210000
# 998  2023-09-04                   okolice Podwala PEÅEN ROZKÅAD!   730000
# 999  2023-09-04    Gotowy dom , wysoki standard ,dobra lokalizacja  1750000
#
#                market surface  \
# 0    market,secondary   59.32
# 1    market,secondary   69.95
# 2      market,primary   51.92
# 3      market,primary   57.93
# 4      market,primary   81.48
# ..                ...     ...
# 995    market,primary   89.07
# 996    market,primary    31.4
# 997    market,primary   27.23
# 998  market,secondary   95.99
# 999    market,primary     184
#
#                                               location remote_support  \
# 0                                   Radom, mazowieckie            NaN
# 1    ul. GÅÃ³wna, Tuchola, Tuchola, tucholski, kuj...            NaN
# 2    ul. RacÅawicka, Grabiszynek, Fabryczna, WrocÅ...            NaN
# 3    ul. ks. Jerzego PopieÅuszki, ZagÃ³rze PÃ³Åno...            NaN
# 4    ul. Zuzanny MaÅaszczyckiej, WÃ³lka MiÅska, M...           true
# ..                                                 ...            ...
# 995        Starogard GdaÅski, starogardzki, pomorskie           true
# 996                       Centrum, ChorzÃ³w, ÅlÄ
# skie           true
# 997              Åwidnica, Åwidnicki, dolnoÅlÄ
# skie           true
# 998         Tarnogaj, Krzyki, WrocÅaw, dolnoÅlÄ
# skie            NaN
# 999  ul. dr. Jana Piltza 12, Kobierzyn, DÄbniki, K...           true
#
#     lighting advertiser_type  \
# 0        NaN          agency
# 1        NaN          agency
# 2        NaN       developer
# 3        NaN          agency
# 4        NaN         private
# ..       ...             ...
# 995      NaN         private
# 996      NaN          agency
# 997      NaN          agency
# 998      NaN          agency
# 999      NaN         private
#
#                                            description  no_of_rooms  \
# 0    - - - KupujÄ
# cy nie pÅaci prowizji - - -Do sp...          3.0
# 1    Sprzedam mieszkanie 2-pokojowe zlokalizowane w...          2.0
# 2    \r\n2-pokojowe mieszkanie poÅoÅ¼one na 1 piÄ...          2.0
# 3    Ð ÑÐ¾Ð´Ð°Ð¶ Ð½Ð¾Ð²Ð¸Ñ
#  ÐºÐ²Ð°ÑÑÐ¸Ñ. Ð¡ÑÐ...          2.0
# 4    Segmenty na sprzedaÅ¼ w Karolinie/k. MiÅska M...          4.0
# ..                                                 ...          ...
# 995  PROGRAM BEZPIECZNY KREDYT 2%\r\n\r\nMy juÅ¼ je...          4.0
# 996  *BEZPOÅREDNIO *** BEZ AGENCJI I PROWIZJI *** ...          2.0
# 997  \r\nOstatnia kawalerka z ogrÃ³dkiem w nowej in...          1.0
# 998  SUPER OFERTA!Ciche mieszkanie 3-pokojowe dwust...          3.0
# 999  \r\nGotowy dom ,bezpoÅrednio od Developera, i...          6.0
#
#        form_of_property                                                url  \
# 0    peÅna wÅasnoÅÄ  https://www.otodom.pl/pl/oferta/radom-os-ustro...
# 1    peÅna wÅasnoÅÄ  https://www.otodom.pl/pl/oferta/sprzedam-2-pok...
# 2    peÅna wÅasnoÅÄ  https://www.otodom.pl/pl/oferta/raclawicka-pla...
# 3    peÅna wÅasnoÅÄ  https://www.otodom.pl/pl/oferta/sosnowiec-mies...
# 4                   NaN  https://www.otodom.pl/pl/oferta/segmenty-na-sp...
# ..                  ...                                                ...
# 995  peÅna wÅasnoÅÄ  https://otodom.pl/pl/oferta/bezczynszowe-osied...
# 996  peÅna wÅasnoÅÄ  https://otodom.pl/pl/oferta/okazja-piekna-kawa...
# 997  peÅna wÅasnoÅÄ  https://otodom.pl/pl/oferta/ogrodek-najlepsza-...
# 998  peÅna wÅasnoÅÄ  https://otodom.pl/pl/oferta/okolice-podwala-pe...
# 999                 NaN  https://otodom.pl/pl/oferta/gotowy-dom-wysoki-...
#
#      is_for_sale posting_id
# 0           True      4hFJH
# 1           True      4inHn
# 2           True      4iKtI
# 3           True      4hirJ
# 4           True      4kQpd
# ..           ...        ...
# 995         True      4lQdg
# 996         True      4i3PP
# 997         True      4l9T9
# 998         True      4jXK7
# 999         True      4ljMd
#
# [1000 rows x 15 columns]

# %% [markdown]
# ### 6. Custom indexing while reading csv file

# %%
file_path = './data/Athletes.csv'
athletes = pd.read_csv(file_path, encoding='latin1', index_col='PersonName') #---><Creates the dataframe with PersonName as an index><---
athletes
# Out:
#                        Country           Discipline
# PersonName
# AALERUD Katrine         Norway         Cycling Road
# ABAD Nestor              Spain  Artistic Gymnastics
# ABAGNALE Giovanni        Italy               Rowing
# ABALDE Alberto           Spain           Basketball
# ABALDE Tamara            Spain           Basketball
# ...                        ...                  ...
# ZWICKER Martin Detlef  Germany               Hockey
# ZWOLINSKA Klaudia       Poland         Canoe Slalom
# ZYKOVA Yulia               ROC             Shooting
# ZYUZINA Ekaterina          ROC              Sailing
# ZYZANSKA Sylwia         Poland              Archery
#
# [11085 rows x 2 columns]

# %% [markdown]
# ### 7. Sorting the created index

# %%
#Ascending & Descending order of sorting
athletes.sort_index() #--->< Ascending Order ><---
athletes.sort_index(ascending=False) #--->< Descending Order ><---
# Out:
#                                         Country           Discipline
# PersonName
# von MARTELS Chris                        Canada           Equestrian
# von ECKERMANN Henrik                     Sweden           Equestrian
# von BREDOW-WERNDL Jessica               Germany           Equestrian
# van der WESTHUYZEN Jean               Australia         Canoe Sprint
# van der WEERDEN Mink Alphons Louis  Netherlands               Hockey
# ...                                         ...                  ...
# ABALDE Tamara                             Spain           Basketball
# ABALDE Alberto                            Spain           Basketball
# ABAGNALE Giovanni                         Italy               Rowing
# ABAD Nestor                               Spain  Artistic Gymnastics
# AALERUD Katrine                          Norway         Cycling Road
#
# [11085 rows x 2 columns]

# %%
#Inplace sorting the index
athletes.sort_index(inplace=True) #---><Sort the index - inplace><---
athletes
# Out:
#                                         Country           Discipline
# PersonName
# AALERUD Katrine                          Norway         Cycling Road
# ABAD Nestor                               Spain  Artistic Gymnastics
# ABAGNALE Giovanni                         Italy               Rowing
# ABALDE Alberto                            Spain           Basketball
# ABALDE Tamara                             Spain           Basketball
# ...                                         ...                  ...
# van der WEERDEN Mink Alphons Louis  Netherlands               Hockey
# van der WESTHUYZEN Jean               Australia         Canoe Sprint
# von BREDOW-WERNDL Jessica               Germany           Equestrian
# von ECKERMANN Henrik                     Sweden           Equestrian
# von MARTELS Chris                        Canada           Equestrian
#
# [11085 rows x 2 columns]
